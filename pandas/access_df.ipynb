# %% [markdown]
# ### Dataframe manipulation: Indexing, selecting, assigning

# %% [markdown]
# Data from kaggle: https://www.kaggle.com/datasets/uom190346a/disease-symptoms-and-patient-profile-dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/nathanewer/nwe/cheat/pandas/Disease_symptom_and_patient_profile_dataset.csv')

# %%
df
# Out:
#          Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 0      Influenza   Yes    No     Yes                  Yes   19  Female
# 1    Common Cold    No   Yes     Yes                   No   25  Female
# 2         Eczema    No   Yes     Yes                   No   25  Female
# 3         Asthma   Yes   Yes      No                  Yes   25    Male
# 4         Asthma   Yes   Yes      No                  Yes   25    Male
# ..           ...   ...   ...     ...                  ...  ...     ...
# 344       Stroke   Yes    No     Yes                   No   80  Female
# 345       Stroke   Yes    No     Yes                   No   85    Male
# 346       Stroke   Yes    No     Yes                   No   85    Male
# 347       Stroke   Yes    No     Yes                   No   90  Female
# 348       Stroke   Yes    No     Yes                   No   90  Female
#
#     Blood Pressure Cholesterol Level Outcome Variable
# 0              Low            Normal         Positive
# ...

# %%
df2 = pd.DataFrame({"AAA": [4, 5, 6, 7], 
                    "BBB": [10, 20, 30, 40], 
                    "CCC": [100, 50, -30, -50]})

# %%
df2
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %% [markdown]
# #### Indexing:

# %% [markdown]
# Can access as though object or dictionary:

# %%
df2.AAA
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# Name: AAA, dtype: int64

# %%
df2['AAA']
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# Name: AAA, dtype: int64

# %% [markdown]
# 2nd method is better as can be used to access df columns with spaces in the name:

# %%
df['Blood Pressure'][:5]
# Out:
# 0       Low
# 1    Normal
# 2    Normal
# 3    Normal
# 4    Normal
# Name: Blood Pressure, dtype: object

# %%
#!!!!
df.blood pressure[:5]
# Out:
#   Cell In[24], line 1
#     df.blood pressure[:5]
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# Swapping columns:

# %%
df2[['AAA', 'BBB']] = df2[['BBB', 'AAA']]
df2
# Out:
#    AAA  BBB  CCC
# 0   10    4  100
# 1   20    5   50
# 2   30    6  -30
# 3   40    7  -50

# %% [markdown]
# ##### Index based selection:

# %% [markdown]
# ##### Label based selection:

# %%
df.loc[(df.Cough == 'Yes') & (df.Age >= 20)]
# Out:
#              Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 1        Common Cold    No   Yes     Yes                   No   25  Female
# 2             Eczema    No   Yes     Yes                   No   25  Female
# 3             Asthma   Yes   Yes      No                  Yes   25    Male
# 4             Asthma   Yes   Yes      No                  Yes   25    Male
# 6          Influenza   Yes   Yes     Yes                  Yes   25  Female
# ..               ...   ...   ...     ...                  ...  ...     ...
# 334  Prostate Cancer   Yes   Yes      No                   No   70    Male
# 335    Schizophrenia    No   Yes     Yes                   No   70    Male
# 338           Stroke    No   Yes      No                   No   70    Male
# 339           Stroke    No   Yes      No                   No   70    Male
# 341      Tonsillitis   Yes   Yes     Yes                   No   70  Female
#
#     Blood Pressure Cholesterol Level Outcome Variable
# ...

# %%
df[(df['Cough'] == 'Yes') & (df['Age'] >= 20)]
# Out:
#              Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 1        Common Cold    No   Yes     Yes                   No   25  Female
# 2             Eczema    No   Yes     Yes                   No   25  Female
# 3             Asthma   Yes   Yes      No                  Yes   25    Male
# 4             Asthma   Yes   Yes      No                  Yes   25    Male
# 6          Influenza   Yes   Yes     Yes                  Yes   25  Female
# ..               ...   ...   ...     ...                  ...  ...     ...
# 334  Prostate Cancer   Yes   Yes      No                   No   70    Male
# 335    Schizophrenia    No   Yes     Yes                   No   70    Male
# 338           Stroke    No   Yes      No                   No   70    Male
# 339           Stroke    No   Yes      No                   No   70    Male
# 341      Tonsillitis   Yes   Yes     Yes                   No   70  Female
#
#     Blood Pressure Cholesterol Level Outcome Variable
# ...

# %%
df2.loc[(df2["BBB"] < 25) & (df2["CCC"] >= -40), "AAA"]
# Out:
# 0    4
# 1    5
# Name: AAA, dtype: int64

# %%
df2[(df2["BBB"] < 25) & (df2["CCC"] >= -40)]
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
